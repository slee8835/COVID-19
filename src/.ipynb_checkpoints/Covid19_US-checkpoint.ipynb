# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import *

# %% [markdown]
# # Data cleaning- johns hopkins dataset
# first, reading in the latest US reported daily report (4/16)

# %%
df = pd.read_csv("../csse_covid_19_data/csse_covid_19_daily_reports_us/04-21-2020.csv")
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-04-21 23:40:34  32.3182  -86.9023
# 1          Alaska             US  2020-04-21 23:40:34  61.3707 -152.4044
# 2  American Samoa             US  2020-04-21 23:40:34 -14.2710 -170.1320
# 3         Arizona             US  2020-04-21 23:40:34  33.7298 -111.4312
# 4        Arkansas             US  2020-04-21 23:40:34  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 0       5317     183        NaN  5134.0   1.0     113.395538        48526.0
# 1        329       9      168.0   320.0   2.0      55.039824        11119.0
# 2          0       0        NaN     NaN  60.0       0.000000            3.0
# 3       5256     208     1155.0  5048.0   4.0      72.210528        55152.0
# 4       1990      42      809.0  1948.0   5.0      76.862852        27441.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 0                699.0        3.441790  84000001  USA   1034.912902
# 1                 42.0        2.735562  84000002  USA   1860.145312
# 2                  NaN             NaN        16  ASM      5.391708
# 3                637.0        3.957382  84000004  USA    757.715955
# 4                291.0        2.110553  84000005  USA   1059.896247
#
#    Hospitalization_Rate
# 0             13.146511
# 1             12.765957
# 2                   NaN
# 3             12.119482
# 4             14.623116

# %% [markdown]
# This is the Johns Hopkins dataset. It contains 18 variables.
# We don't need all the variables, taking out some irrelevent variables for this project.

# %%
df.set_index("Province_State", inplace = True)
df.drop(['Last_Update','Lat', "Long_", "FIPS", 'UID', 'ISO3'], axis = 1, inplace = True)

# %%
# for dataframe information is calculated by column
print("dataframe shape:")
display(df.shape)  #59 regions, 11 variables
display(df.info())
df.mean()
# Out:
# dataframe shape:
# (62, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, Alabama to Recovered
# Data columns (total 11 columns):
# Country_Region          62 non-null object
# Confirmed               62 non-null int64
# Deaths                  62 non-null int64
# Recovered               35 non-null float64
# Active                  61 non-null float64
# Incident_Rate           56 non-null float64
# People_Tested           56 non-null float64
# People_Hospitalized     49 non-null float64
# Mortality_Rate          60 non-null float64
# Testing_Rate            56 non-null float64
# Hospitalization_Rate    49 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 5.8+ KB
# None
# Confirmed               13286.870968
# Deaths                    723.306452
# Recovered                3809.171429
# Active                  11536.672131
# Incident_Rate             199.782731
# People_Tested           74199.607143
# People_Hospitalized      2454.448980
# Mortality_Rate              3.862403
# Testing_Rate             1395.232927
# Hospitalization_Rate       13.441394
# dtype: float64

# %%
#dropping the cruises- Diamond Princess and Grand Princess, because they cannot be taken account into social distancing modeling 
#also dropping american samoa, too many NaNs
df.drop(["American Samoa", "Diamond Princess", "Grand Princess", "Recovered", "Veteran Hospitals", "US Military", "Federal Bureau of Prisons"], axis = 0, inplace = True)

#dropping recovered and people_hospitalized column, too many NaNs, also not necessarily useful for this project
df.drop(["Recovered", "People_Hospitalized", "Hospitalization_Rate"], axis = 1, inplace = True)

# Oregon                     1026.384838
# Pennsylvania               1325.529611
# Puerto Rico                 343.866247
# Rhode Island               3712.898625
# South Carolina              818.992158
# South Dakota               1741.424013
# Tennessee                  1647.877685
# Texas                       893.638995
# Utah                       2524.807372
# Vermont                    2147.263880
# Virgin Islands              585.449528
# Virginia                    737.982833
# Washington                 1867.843060
# West Virginia              1720.561936
# Wisconsin                  1013.823175
# Wyoming                    1532.660285

# %% [markdown]
# # Data Visualization
# run some interesting and informative plots

# %%
sns.set(color_codes=True, font_scale = 2.5, rc={'figure.figsize':(50,25)})

# %%
#all regions' accumulated confirmed cases 
sns.barplot(x = df.index, y = df.loc[:, "Confirmed"])  #too messy, break down regions into groups

# %%
sns.barplot(x = df.index[0:10], y = df.loc["Alabama": "Florida", "Confirmed"])

# %%
sns.barplot(x = df.index[10:20], y = df.loc["Georgia": "Louisiana", "Confirmed"])

# %%
sns.barplot(x = df.index[20:30], y = df.loc["Maine": "Nevada", "Confirmed"])

# %%
sns.barplot(x = df.index[30:40], y = df.loc["New Hampshire": "Oregon", "Confirmed"])

# %%
sns.barplot(x = df.index[40:50], y = df.loc["Pennsylvania": "Virgin Islands", "Confirmed"])

# %%
sns.barplot(x = df.index[50:56], y = df.loc["Virginia": "Wyoming", "Confirmed"])

# %%
sns.set(color_codes=True, font_scale = 1, rc={'figure.figsize':(20,10)})

# %%
sns.scatterplot(x="Testing_Rate", y="Mortality_Rate", hue = df.index, data = df)

# %%
#sort states based on confirmed cases in descending order
#most interested in the more effected areas, pick top 10 first 
df_srt = df.sort_values(by ='Confirmed', ascending = False)
df_srt = df_srt.iloc[0:10, :]
top_10 = ['New York','New Jersey','Massachusetts','California','Pennsylvania','Illiois','Michigan','Florida','Louisiana','Texas']

# %%
sns.barplot(x = df_srt.index, y = "Confirmed", data = df_srt)

# %%
df_time = pd.read_csv("../csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv")
df_time.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 4/12/20  4/13/20  4/14/20  4/15/20  4/16/20  \
# 0 -14.2710 -170.1320  ...       0        0        0        0        0
# 1  13.4443  144.7937  ...     133      133      133      135      135
# 2  15.0979  145.6739  ...      11       11       11       13       13
# 3  18.2208  -66.5901  ...     897      903      923      974     1043
# 4  18.3358  -64.8963  ...      51       51       51       51       51
#
#    4/17/20  4/18/20  4/19/20  4/20/20  4/21/20
# 0        0        0        0        0        0
# 1      136      136      136      136      136
# 2       13       14       14       14       14
# 3     1068     1118     1213     1252     1298
# 4       51       53       53       53       53
#
# [5 rows x 102 columns]

# %%
df_time.set_index("Province_State", inplace = True)
# Out:
#                           Country_Region  \
# Province_State
# American Samoa                        US
# Guam                                  US
# Northern Mariana Islands              US
# Puerto Rico                           US
# Virgin Islands                        US
# ...                                  ...
# US Military                           US
# US Military                           US
# Federal Bureau of Prisons             US
# US Military                           US
# Veteran Hospitals                     US
#
#                                                    Combined_Key  1/22/20  \
# Province_State
# American Samoa                               American Samoa, US        0
# Guam                                                   Guam, US        0
# Northern Mariana Islands           Northern Mariana Islands, US        0
# Puerto Rico                                     Puerto Rico, US        0
# Virgin Islands                               Virgin Islands, US        0
# ...                                                         ...      ...
# US Military                       Marine Corps, US Military, US        0
# US Military                               Navy, US Military, US        0
# Federal Bureau of Prisons  Staff, Federal Bureau of Prisons, US        0
# US Military                         Unassigned, US Military, US        0
# Veteran Hospitals                         Veteran Hospitals, US        0
#
#                            1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Province_State
# American Samoa                   0        0        0        0        0
# Guam                             0        0        0        0        0
# Northern Mariana Islands         0        0        0        0        0
# Puerto Rico                      0        0        0        0        0
# Virgin Islands                   0        0        0        0        0
# ...                            ...      ...      ...      ...      ...
# US Military                      0        0        0        0        0
# US Military                      0        0        0        0        0
# Federal Bureau of Prisons        0        0        0        0        0
# US Military                      0        0        0        0        0
# Veteran Hospitals                0        0        0        0        0
#
#                            1/28/20  1/29/20  ...  4/12/20  4/13/20  4/14/20  \
# Province_State                               ...
# American Samoa                   0        0  ...        0        0        0
# Guam                             0        0  ...      133      133      133
# Northern Mariana Islands         0        0  ...       11       11       11
# Puerto Rico                      0        0  ...      897      903      923
# Virgin Islands                   0        0  ...       51       51       51
# ...                            ...      ...  ...      ...      ...      ...
# US Military                      0        0  ...        0        0        0
# US Military                      0        0  ...        0        0        0
# Federal Bureau of Prisons        0        0  ...        0        0        0
# US Military                      0        0  ...        0        0        0
# Veteran Hospitals                0        0  ...        0        0        0
#
#                            4/15/20  4/16/20  4/17/20  4/18/20  4/19/20  \
# Province_State
# American Samoa                   0        0        0        0        0
# Guam                           135      135      136      136      136
# Northern Mariana Islands        13       13       13       14       14
# Puerto Rico                    974     1043     1068     1118     1213
# Virgin Islands                  51       51       51       53       53
# ...                            ...      ...      ...      ...      ...
# US Military                      0        0        0        0        0
# US Military                      0        0        0        0        0
# Federal Bureau of Prisons        0        0        0        0        0
# US Military                      0        0        0        0        0
# Veteran Hospitals                0        0        0        0        0
#
#                            4/20/20  4/21/20
# Province_State
# American Samoa                   0        0
# Guam                           136      136
# Northern Mariana Islands        14       14
# Puerto Rico                   1252     1298
# Virgin Islands                  53       53
# ...                            ...      ...
# US Military                      0      253
# US Military                      0     1631
# Federal Bureau of Prisons        0      319
# US Military                      0     1810
# Veteran Hospitals                0     5599
#
# [3269 rows x 93 columns]

# %%
df_time
#df_time.drop(["UID", "iso2", "iso3", "code3", "FIPS", "Admin2", "Lat", "Long_"], axis = 1, inplace = True)
df_time.drop(["American Samoa", "Veteran Hospitals", "US Military", "Federal Bureau of Prisons"], axis = 0, inplace = True)

# %%
df_time
# Out:
#                          Country_Region                  Combined_Key  \
# Province_State
# Guam                                 US                      Guam, US
# Northern Mariana Islands             US  Northern Mariana Islands, US
# Puerto Rico                          US               Puerto Rico, US
# Virgin Islands                       US            Virgin Islands, US
# Alabama                              US          Autauga, Alabama, US
# ...                                 ...                           ...
# Utah                                 US        Central Utah, Utah, US
# Utah                                 US      Southeast Utah, Utah, US
# Utah                                 US      Southwest Utah, Utah, US
# Utah                                 US           TriCounty, Utah, US
# Utah                                 US        Weber-Morgan, Utah, US
#
#                           1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Province_State
# Guam                            0        0        0        0        0
# Northern Mariana Islands        0        0        0        0        0
# Puerto Rico                     0        0        0        0        0
# Virgin Islands                  0        0        0        0        0
# Alabama                         0        0        0        0        0
# ...                           ...      ...      ...      ...      ...
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
#
#                           1/27/20  1/28/20  1/29/20  ...  4/12/20  4/13/20  \
# Province_State                                       ...
# Guam                            0        0        0  ...      133      133
# Northern Mariana Islands        0        0        0  ...       11       11
# Puerto Rico                     0        0        0  ...      897      903
# Virgin Islands                  0        0        0  ...       51       51
# Alabama                         0        0        0  ...       19       19
# ...                           ...      ...      ...  ...      ...      ...
# Utah                            0        0        0  ...        0        0
# Utah                            0        0        0  ...        0        0
# Utah                            0        0        0  ...        0        0
# Utah                            0        0        0  ...        0        0
# Utah                            0        0        0  ...        0        0
#
#                           4/14/20  4/15/20  4/16/20  4/17/20  4/18/20  \
# Province_State
# Guam                          133      135      135      136      136
# Northern Mariana Islands       11       13       13       13       14
# Puerto Rico                   923      974     1043     1068     1118
# Virgin Islands                 51       51       51       51       53
# Alabama                        23       24       26       26       25
# ...                           ...      ...      ...      ...      ...
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
# Utah                            0        0        0        0        0
#
#                           4/19/20  4/20/20  4/21/20
# Province_State
# Guam                          136      136      136
# Northern Mariana Islands       14       14       14
# Puerto Rico                  1213     1252     1298
# Virgin Islands                 53       53       53
# Alabama                        26       28       30
# ...                           ...      ...      ...
# Utah                           15       17       17
# Utah                            6        7        7
# Utah                           66       70       70
# Utah                           10       10       10
# Utah                          119      124      126
#
# [3260 rows x 93 columns]

# %%
#extract out all new york data
df_ny = df_time.loc[["New York", ]]
df_ny.drop(["Country_Region", "Combined_Key"], axis = 1, inplace = True)
#combined all rows of ny into one dataframe
ny_sum = df_ny.sum(axis=0)
ny_sum = ny_sum.to_frame()

# %%
#set column name to confirmed
ny_sum.columns = ["Confirmed"]
#date that WHO declared COVID as a pandemic 
ny_sum = ny_sum.loc["3/11/20": ,]

# %%
sns.lineplot(x=ny_sum.index, y="Confirmed", data = ny_sum)

# %%
top_10
df_time10 = df_time.loc[['New York','New Jersey','Massachusetts','California','Pennsylvania','Illiois','Michigan','Florida','Louisiana','Texas']]
df_time10.drop(["Country_Region", "Combined_Key"], axis = 1, inplace = True)
df_time10.loc['New York'].sum(axis = 0)
# Out:
# C:\Users\sharo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
# 1/22/20         0.0
# 1/23/20         0.0
# 1/24/20         0.0
# 1/25/20         0.0
# 1/26/20         0.0
#              ...
# 4/17/20    230597.0
# 4/18/20    241712.0
# 4/19/20    247815.0
# 4/20/20    253060.0
# 4/21/20    258361.0
# Length: 91, dtype: float64
